# %% [markdown]
# Ramadhita Atifa Hendri
# 121450131
# RC

# %% [markdown]
# # **1. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural dibandingkan dengan object oriented (minimal 3) !**

# %% [markdown]
# Kekurangan Procedural dibandingkan Object Oriented
# ![2023-02-07 (11).png](data:image/png;base64,...)

# %% [markdown]
# Kelebihan Procedural dibandingkan Functional
# ![2023-02-07 (12).png](data:image/png;base64,...)

# %% [markdown]
# # **2. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma object oriented dibandingkan dengan functional (minimal 3) !**

# %% [markdown]
# Kekurangan Object Oriented dibandingkan Procedural
# ![2023-02-07 (13).png](data:image/png;base64,...)

# %% [markdown]
# Kelebihan Object Oriented dibandingkan Procedural
# ![2023-02-07 (14).png](data:image/png;base64,...)

# %% [markdown]
# # **3. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural dibandingkan dengan functional (minimal 3) !**

# %% [markdown]
# Kekurangan Procedural dibandingkan Functional
# ![2023-02-07 (15).png](data:image/png;base64,...)

# %% [markdown]
# Kelebihan Procedural dibandingkan Functional
# ![2023-02-07 (16).png](data:image/png;base64,...)

# %% [markdown]
# # **4. Apa yang dimaksud dengan pure functional programming language?**

# %% [markdown]
# Pure functional programming language adalah paradigma pemrograman yang ada sebelum munculnya object-oriented. Pada dasarnya, functional programming memperlakukan fungsi dan data sebagai immutable atau tidak berubah. Dalam functional programmin, function tidak boleh mengubah data asli atau status program.

# %% [markdown]
# #**5. Dari bahasa pemrograman FP di slide sebelumnya ( slide 14 ) , manakah yang termasuk pure functional programming language?**

# %% [markdown]
# Yang termasuk ke dalam pure functional programming adalah Lisp, Haskell, dan Standard ML

# %% [markdown]
# # **6. Membuat program Simple Password encryption, dengan ketentuan**
#
#
# ### 1.   Input password bertipe string dengan batasan panjang password 100 karakter
# ### 2.   Setiap karakter dari string tersebut diubah menjadi ASCII value
# ### 3.   Kemudian setiap ASCII value tersebut dikembangkan menjadi 3 value dengan dilakukan operasi berikut:
#   1. Value pertama dibagi dengan integer 26 kemudian
# dibulatkan dan dijumlahkan dengan 80 kemudian diubah
# kembali menjadi karakter
#   2. Value kedua dihitung sisa bagi dengan 26 kemudian
# dijumlahkan dengan 80 kemudian diubah kembali menjadi
# karakter
#   3. Value ketiga adalah karakter ‘+’ jika value pertama lebih
# besar dari value kedua, atau value ketiga adalah karakter ‘-’
# jika value pertama tidak lebih besar dari value kedua
#
# ### 4.    Deretkan value pertama, kedua dan ketiga untuk setiap karakter dalam password tersebut sehingga didapatkan password dalam bentuk baru

# %%
# fungsi enkripsi
def enkripsi(password):
  # jika panjang karakter <100
  if len(password) > 100 or len(password) == 0:
    print("Enter 1-100 characters")
  else:
    # untuk mengubah setiap karakter menjadi kode ascii kemudian ditampung dalam list
    ascii = [str(ord(i)) for i in password]
    # untuk membuat 3 value dari setiap kode ascii kemudian menggabungkan semuanya
    enkri = ''.join(chr((int(j)//26)+80)+chr((int(j)%26)+80)+('+' if (int(j)//26)+80 > (int(j)%26)+80 else '-') for j in ascii)
    # untuk menampilkan hasil 
    print("The encryption password is: ", enkri)

# fungsi dekripsi
def dekripsi(password):
  # split 3 value 
  split_ps = [(password[k:k+3]) for k in range(0, len(password), 3)]
  # unttuk membuat 3 value kembali ke kode ascii kemudian ke karakter asli dan menggabungkan semuanya
  dekri = ''.join(chr(((ord(list(z)[0])-80)*26)+(ord(list(z)[1])-80)) for z in split_ps)
  # untuk menampilkan hasil dekripsi
  print("The password is: ", dekri)

# %%
# enkripsi
password = input("Enter Password: ")
enkripsi(password)
# Out:
# Enter Password: sainsdata2023
# The encryption password is:  T[-Sc-TQ+TV-T[-Sf-Sc-T\-Sc-Qh-Qf-Qh-Qi-
